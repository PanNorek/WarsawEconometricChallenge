# %%
import pandas as pd

# %%
data = pd.read_csv('data/chunks/chunks/chunk1.csv')
# Out:
# /tmp/ipykernel_8767/2057212158.py:1: DtypeWarning: Columns (22,23,51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/chunks/chunks/chunk1.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'TICKET_NUMBER', 'BOOKING_ID', 'SALES_DATE.x',
#        'SALES_MARKET', 'SALES_CHANNEL.x', 'TRIP_TYPE', 'BOOKING_WINDOW_D',
#        'STAY_LENGTH_D', 'BOOKING_LONG_HOUL_FLAG', 'BOOKING_DOMESTIC_FLAG',
#        'FLIGHT_COUPONS', 'SEGMENTS', 'PAX_N', 'INTINERARY',
#        'BOOKING_ORIGIN_AIRPORT', 'BOOKING_ORIGIN_COUNTRY_CODE',
#        'BOOKING_DEPARTURE_TIME_UTC', 'BOOKING_DESTINATION_AIRPORT',
#        'BOOKING_DESTINATION_COUNTRY_CODE', 'BOOKING_ARRIVAL_TIME_UTC',
#        'UPGRADED_FLAG.x', 'UPGRADE_SALES_DATE.x', 'UPGRADE_TYPE.x',
#        'ORIGINAL_TICKET_NUMBER', 'FORM_OF_PAYMENT', 'CURRENCY.x',
#        'TOTAL_PRICE.x', 'TOTAL_PRICE_PLN.x', 'PAX_GENDER', 'PAX_TYPE',
#        'CORPORATE_CONTRACT_FLG', 'LOYAL_CUSTOMER', 'LOYAL_CUSTOMER_ID',
#        'LOYAL_CUSTOMER_DATE_OF_BIRTH', 'LOYAL_CUSTOMER_REGISTERED_DATE',
#        'COUPON_NUMBER.x', 'ORIGIN_AIRPORT_CODE.x',
#        'DESTINATION_AIRPORT_CODE.x', 'FLIGHT_DATE_LOCAL',
# ...

# %%
col = ['TRIP_TYPE','STAY_LENGTH_D','BOOKING_LONG_HOUL_FLAG','BOOKING_DOMESTIC_FLAG','PAX_N','INTINERARY',
        'PAX_GENDER', 'PAX_TYPE','CORPORATE_CONTRACT_FLG','FLIGHT_RANGE','LOYAL_CUSTOMER_REGISTERED_DATE',
        'BOOKED_CLASS','BOOKED_CABIN','AIRCRAFT_TYPE','UPGRADED_FLAG.x']

# %%
data = data[col]

# %%
import seaborn as sns



sns.pairplot(data, kind="kde")
