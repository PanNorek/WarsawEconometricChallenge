# %%
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('data/chunks/chunks/chunk1.csv')
# Out:
# /tmp/ipykernel_9141/2057212158.py:1: DtypeWarning: Columns (22,23,51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/chunks/chunks/chunk1.csv')

# %%
sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/oleh/Рабочий стол/WarsawEconometricChallenge/visual.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/oleh/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/WarsawEconometricChallenge/visual.ipynb#ch0000002?line=0'>1</a> sns.pairplot(data)
#
# File ~/Рабочий стол/WarsawEconometricChallenge/venv/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      <a href='file:///home/oleh/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/WarsawEconometricChallenge/venv/lib/python3.8/site-packages/seaborn/_decorators.py?line=35'>36</a>     warnings.warn(
# ...

# %%
data_c = pd.read_csv('data/clear_chunks/chunk_clear1.csv')

# %%
data_c.columns
# Out:
# Index(['Unnamed: 0', 'SALES_CHANNEL.x', 'TRIP_TYPE', 'STAY_LENGTH_D',
#        'BOOKING_LONG_HOUL_FLAG', 'BOOKING_DOMESTIC_FLAG', 'PAX_N',
#        'INTINERARY', 'UPGRADED_FLAG.x', 'UPGRADE_TYPE.x', 'FORM_OF_PAYMENT',
#        'TOTAL_PRICE_PLN.x', 'PAX_GENDER', 'PAX_TYPE', 'CORPORATE_CONTRACT_FLG',
#        'LOYAL_CUSTOMER', 'ORIGIN_AIRPORT_CODE.x', 'DESTINATION_AIRPORT_CODE.x',
#        'FLIGHT_DATE_LOCAL', 'FLIGHT_RANGE', 'BOOKED_CLASS', 'BOOKED_CABIN',
#        'AIRCRAFT_TYPE', 'UPGRADED_FLAG.y', 'UPGRADE_TYPE.y', 'SALES_CHANNEL.y',
#        'COD_RFISC', 'SUBCATEGORY', 'CATEGORY', 'GROUP', 'TOTAL_PRICE_PLN.y'],
#       dtype='object')

# %%
col = ['SALES_CHANNEL.x', 'TRIP_TYPE', 'STAY_LENGTH_D']

data_cc = data_c[col]

# %%
sns.pairplot(data_cc)
